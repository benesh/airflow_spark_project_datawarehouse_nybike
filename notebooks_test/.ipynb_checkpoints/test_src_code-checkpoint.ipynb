# %%
import os 
# os.chdir('include/jobs/pyspark')


from datetime import datetime
from connect_db import SinkDB, QueryDB,ConnectDB,ConfigDB
from etl_metadata import Audit_Batch_Etl, log_to_audit_metadata

# os.getcwd()
# os.chdir('include/jobs/pyspark')
dict_helio=[{'hellomaje':'jojjo','koto':'loool','pool':25631},{'hello':'vouza'}]
start = datetime.now()
end= datetime.now()
duration = end - start

# %%
metadata = Audit_Batch_Etl(
        process_name='test_dq',
        start_time=start,
        end_time=end,
        duration=end - start,
        rows_processed =45668,
        status='SUCCES',
        process_period='203001',
        year=2013,
        month=4,
        data_to_process_id_fk=1,
        error_message='hello error ici',
        details_result=dict_helio
    )

log_to_audit_metadata(metadata)

# %%
dict_helio
# Out:
# {'hellomaje': 'jojjo', 'koto': 'loool'}

# %%
# !ls include/jobs/pyspark
# Out:
# __init___.py			 job_etl_bronze_nybike.py
# __pycache__			 job_etl_gold_stage.py
# connect_db.py			 job_etl_silver_nybike.py
# data_quality.py			 model_data.py
# etl_metadata.py			 readers.py
# etl_nybike_to_stage_database.py  settings.py
# get_spark_session.py		 sinkers.py
# helpers_utils.py		 steps_pipeline.py
# interfaces.py			 test_python.py
# job_dq_silver_layer_publish.py	 transformers.py

# %%
dict_tets= {
    'hell':{'status':True},
    'booze':{'status':True},
    'nougte':{'status':True}
}

# %%
if all(r['status'] for r in result):
    print("all True")
else:
    print("one false")
# Out:
# all True

# %%
result = [
    {'status': True},
    {'status': True},
    {'status': True}
]

# %%
int(True*False)
# Out:
# 0

# %%
def get_all_valu(parma:dict)-> bool:
