# %% [raw]
# ETL bronze lunch job

# %%
! spark-submit \
  --master local[*] \
  --packages "org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.5.0,org.projectnessie.nessie-integrations:nessie-spark-extensions-3.5_2.12:0.102.5,software.amazon.awssdk:bundle:2.20.131,software.amazon.awssdk:url-connection-client:2.20.131,org.apache.hadoop:hadoop-aws:3.3.4,com.amazonaws:aws-java-sdk-bundle:1.12.262" \
  --conf "spark.sql.extensions=org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions,org.projectnessie.spark.extensions.NessieSparkSessionExtensions" \
  --conf "spark.sql.catalog.nybike_catalog=org.apache.iceberg.spark.SparkCatalog" \
  --conf "spark.sql.catalog.nybike_catalog.uri=${NESSIE_URI}" \
  --conf "spark.sql.catalog.nybike_catalog.ref=main" \
  --conf "spark.sql.catalog.nybike_catalog.authentication.type=NONE" \
  --conf "spark.sq   l.catalog.nybike_catalog.catalog-impl=org.apache.iceberg.nessie.NessieCatalog" \
  --conf "spark.sql.catalog.nybike_catalog.warehouse=${WAREHOUSE}" \
  --conf "spark.sql.catalog.nybike_catalog.io-impl=org.apache.iceberg.aws.s3.S3FileIO" \
  --conf "spark.sql.catalog.nybike_catalog.s3.endpoint=${AWS_S3_ENDPOINT}" \
  --conf "spark.sql.catalog.nybike_catalog.s3.path-style-access=true" \
  --conf "spark.hadoop.fs.s3a.access.key=${AWS_ACCESS_KEY_ID}" \
  --conf "spark.hadoop.fs.s3a.secret.key=${AWS_SECRET_ACCESS_KEY}" \
  --conf "spark.hadoop.fs.s3a.endpoint=${AWS_S3_ENDPOINT}" \
  --conf "spark.hadoop.fs.s3a.path.style.access=true" \
  --conf "spark.hadoop.fs.s3a.impl=org.apache.hadoop.fs.s3a.S3AFileSystem" \
    --files ./include/resources/configs/config_etl_bronze_from_s3_to_iceberg.yaml \
    --py-files ./include/jobs/pyspark/interfaces.py,./include/jobs/pyspark/readers.py,./include/jobs/pyspark/sinkers.py,./include/jobs/pyspark/etl_metadata.py,./include/jobs/pyspark/helpers_utils.py,./include/jobs/pyspark/transformers.py,./include/jobs/pyspark/steps_pipeline.py \
    ./include/jobs/pyspark/job_etl_bronze_nybike.py

# %% [raw]
# ETL Silver Layer lunch job

# %%
! spark-submit \
  --master local[*] \
  --packages "org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.10.0,org.projectnessie.nessie-integrations:nessie-spark-extensions-3.5_2.12:0.104.5,software.amazon.awssdk:bundle:2.20.131,software.amazon.awssdk:url-connection-client:2.20.131,org.apache.hadoop:hadoop-aws:3.3.4,com.amazonaws:aws-java-sdk-bundle:1.12.262" \
  --conf "spark.sql.extensions=org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions,org.projectnessie.spark.extensions.NessieSparkSessionExtensions" \
  --conf "spark.sql.catalog.nybike_catalog=org.apache.iceberg.spark.SparkCatalog" \
  --conf "spark.sql.catalog.nybike_catalog.uri=${NESSIE_URI}" \
  --conf "spark.sql.catalog.nybike_catalog.ref=main" \
  --conf "spark.sql.catalog.nybike_catalog.authentication.type=NONE" \
  --conf "spark.sql.catalog.nybike_catalog.catalog-impl=org.apache.iceberg.nessie.NessieCatalog" \
  --conf "spark.sql.catalog.nybike_catalog.warehouse=${WAREHOUSE}" \
  --conf "spark.sql.catalog.nybike_catalog.io-impl=org.apache.iceberg.aws.s3.S3FileIO" \
  --conf "spark.sql.catalog.nybike_catalog.s3.endpoint=${AWS_S3_ENDPOINT}" \
  --conf "spark.sql.catalog.nybike_catalog.s3.path-style-access=true" \
  --conf "spark.hadoop.fs.s3a.access.key=${AWS_ACCESS_KEY_ID}" \
  --conf "spark.hadoop.fs.s3a.secret.key=${AWS_SECRET_ACCESS_KEY}" \
  --conf "spark.hadoop.fs.s3a.endpoint=${AWS_S3_ENDPOINT}" \
  --conf "spark.hadoop.fs.s3a.path.style.access=true" \
  --conf "spark.hadoop.fs.s3a.impl=org.apache.hadoop.fs.s3a.S3AFileSystem" \
    --files ./include/resources/configs/config_etl_silver_v2_iceberg.yaml \
    --py-files ./include/jobs/pyspark/interfaces.py,./include/jobs/pyspark/readers.py,./include/jobs/pyspark/sinkers.py,./include/jobs/pyspark/etl_metadata.py,./include/jobs/pyspark/helpers_utils.py,./include/jobs/pyspark/transformers.py,./include/jobs/pyspark/steps_pipeline.py \
    ./include/jobs/pyspark/job_etl_silver_nybike.py

# %% [raw]
# Data quality lunch job silver

# %%
! spark-submit \
  --master local[*] \
  --packages "org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.10.0,org.projectnessie.nessie-integrations:nessie-spark-extensions-3.5_2.12:0.104.5,software.amazon.awssdk:bundle:2.20.131,software.amazon.awssdk:url-connection-client:2.20.131,org.apache.hadoop:hadoop-aws:3.3.4,com.amazonaws:aws-java-sdk-bundle:1.12.262" \
  --conf "spark.sql.extensions=org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions,org.projectnessie.spark.extensions.NessieSparkSessionExtensions" \
  --conf "spark.sql.catalog.nybike_catalog=org.apache.iceberg.spark.SparkCatalog" \
  --conf "spark.sql.catalog.nybike_catalog.uri=${NESSIE_URI}" \
  --conf "spark.sql.catalog.nybike_catalog.ref=main" \
  --conf "spark.sql.catalog.nybike_catalog.authentication.type=NONE" \
  --conf "spark.sql.catalog.nybike_catalog.catalog-impl=org.apache.iceberg.nessie.NessieCatalog" \
  --conf "spark.sql.catalog.nybike_catalog.warehouse=${WAREHOUSE}" \
  --conf "spark.sql.catalog.nybike_catalog.io-impl=org.apache.iceberg.aws.s3.S3FileIO" \
  --conf "spark.sql.catalog.nybike_catalog.s3.endpoint=${AWS_S3_ENDPOINT}" \
  --conf "spark.sql.catalog.nybike_catalog.s3.path-style-access=true" \
  --conf "spark.hadoop.fs.s3a.access.key=${AWS_ACCESS_KEY_ID}" \
  --conf "spark.hadoop.fs.s3a.secret.key=${AWS_SECRET_ACCESS_KEY}" \
  --conf "spark.hadoop.fs.s3a.endpoint=${AWS_S3_ENDPOINT}" \
  --conf "spark.hadoop.fs.s3a.path.style.access=true" \
  --conf "spark.hadoop.fs.s3a.impl=org.apache.hadoop.fs.s3a.S3AFileSystem" \
    --files ./include/resources/configs/config_job_dq_silver.yaml \
    --py-files ./include/jobs/pyspark/interfaces.py,./include/jobs/pyspark/readers.py,./include/jobs/pyspark/sinkers.py,./include/jobs/pyspark/etl_metadata.py,./include/jobs/pyspark/helpers_utils.py,./include/jobs/pyspark/data_quality.py,./include/jobs/pyspark/steps_pipeline.py \
    ./include/jobs/pyspark/job_dq_silver_layer_publish.py

# %% [raw]
# ETL gold - Layer

# %%
! spark-submit \
  --master local[*] \
  --packages "org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.10.0,org.projectnessie.nessie-integrations:nessie-spark-extensions-3.5_2.12:0.104.5,software.amazon.awssdk:bundle:2.20.131,software.amazon.awssdk:url-connection-client:2.20.131,org.apache.hadoop:hadoop-aws:3.3.4,com.amazonaws:aws-java-sdk-bundle:1.12.262" \
  --conf "spark.sql.extensions=org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions,org.projectnessie.spark.extensions.NessieSparkSessionExtensions" \
  --conf "spark.sql.catalog.nybike_catalog=org.apache.iceberg.spark.SparkCatalog" \
  --conf "spark.sql.catalog.nybike_catalog.uri=${NESSIE_URI}" \
  --conf "spark.sql.catalog.nybike_catalog.ref=main" \
  --conf "spark.sql.catalog.nybike_catalog.authentication.type=NONE" \
  --conf "spark.sql.catalog.nybike_catalog.catalog-impl=org.apache.iceberg.nessie.NessieCatalog" \
  --conf "spark.sql.catalog.nybike_catalog.warehouse=${WAREHOUSE}" \
  --conf "spark.sql.catalog.nybike_catalog.io-impl=org.apache.iceberg.aws.s3.S3FileIO" \
  --conf "spark.sql.catalog.nybike_catalog.s3.endpoint=${AWS_S3_ENDPOINT}" \
  --conf "spark.sql.catalog.nybike_catalog.s3.path-style-access=true" \
  --conf "spark.hadoop.fs.s3a.access.key=${AWS_ACCESS_KEY_ID}" \
  --conf "spark.hadoop.fs.s3a.secret.key=${AWS_SECRET_ACCESS_KEY}" \
  --conf "spark.hadoop.fs.s3a.endpoint=${AWS_S3_ENDPOINT}" \
  --conf "spark.hadoop.fs.s3a.path.style.access=true" \
  --conf "spark.hadoop.fs.s3a.impl=org.apache.hadoop.fs.s3a.S3AFileSystem" \
    --files ./include/resources/configs/config_etl_gold_v2_iceberg.yaml \
    --py-files ./include/jobs/pyspark/interfaces.py,./include/jobs/pyspark/readers.py,./include/jobs/pyspark/sinkers.py,./include/jobs/pyspark/etl_metadata.py,./include/jobs/pyspark/helpers_utils.py,./include/jobs/pyspark/data_quality.py,./include/jobs/pyspark/steps_pipeline.py \
    ./include/jobs/pyspark/job_etl_gold_stage.py

# %%
# !echo $POSTGRES_USER
# Out:
# userdb

# %%
from include.jobs.pyspark.connect_db import QueryDB,ConnectDB,get_db_config
import os

# %%
config_db= get_db_config()
config_db
# Out:
# {'user': 'userdb',
#  'password': 'password_db',
#  'host': 'db-postgres',
#  'port': '5432',
#  'database': 'postgres',
#  'db_prefix': 'postgresql'}

# %%
os.environ.get("PYSPARK_DRIVER_PYTHON")
# Out:
# 'python3'
